# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <h1>SHILPA A S
# <br>data scientist

# %% [markdown]
# _I am interested in data science because i like puzzles_

# %% [markdown]
# <h3>simple addition of 1 + 1<h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1. open_new(www.google.com)
# 2. [1704672.jpg](attachment:880513d9-8279-4337-b746-370c20f6c6d2.jpg)
# 3. | --- | --- | --- |
#    | Stretch/Untouched | ProbDistribution | Accuracy |
#    | --- | --- | --- |
#    | Stretched | Gaussian | .843 |
